# %%
from sklearn.linear_model import LinearRegression
X = [[1], [2], [3], [4], [5], [6], [7], [8]]
y = [3.2, 4.8, 7.1, 8.5, 11.3, 12.4, 15.2, 16.1]
model = LinearRegression()
model.fit(X,y)
print(model.coef_)
print(model.intercept_)
# Out:
# [1.91666667]
# 1.1999999999999957

# %% [markdown]
# **Can see W,B are similar to the ComprehensiveLinearRegression exercise**
