# %% [markdown]
# **W,B = 0.8 , 1.8**

# %% [markdown]
# **y=w*x+b**

# %% [markdown]
# **We will make predict on set x= [6,7,8]**

# %%
x_pred = [6,7,8]
y_pred = []
for i in x_pred:
    pred = 0.8*i+1.8
    y_pred.append(pred)
print(y_pred)
# Out:
# [6.6000000000000005, 7.4, 8.200000000000001]
