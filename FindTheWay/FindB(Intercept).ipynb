# %% [markdown]
# **Because we have W , y_mean, x_mean from FindW(Weights)**

# %% [markdown]
# **y_mean = wx_mean+b**

# %% [markdown]
# **=>b=y_mean-w*x_mean**

# %%
b = 4.2 - 0.8*3
print(b)
# Out:
# 1.7999999999999998
