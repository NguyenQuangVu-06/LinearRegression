# %% [markdown]
# **We set w and b to 0, learning_rate = 0.01 , g_w and g_b was found in GradientW,B **

# %%
g_w,g_b = -22.67,-10
w,b=0,0
learning_rate = 0.01
w_update = w - learning_rate*g_w
b_update = b - learning_rate*g_b
print(w_update,b_update)
# Out:
# 0.2267 0.1
